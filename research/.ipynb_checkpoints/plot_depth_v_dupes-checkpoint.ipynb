# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('graphit.csv')

# %%
df = pd.read_csv('graphit.csv')
df.plot(kind='bar',x='depth', y='dupes', title='depth versus dupes', figsize=(12,6))
plt.show()
df
# Out:
#     depth  dupes
# 0       0      0
# 1       1    112
# 2       2     60
# 3       3     23
# 4       4     14
# 5       5     10
# 6       6      6
# 7       7      4
# 8       8      2
# 9       9      1
# 10     10      1
# 11     11      1
# 12     12      1
# 13     13      1
# 14     14      1
# 15     15      1
# 16     16      1
# 17     17      1
# 18     18      1
# 19     19      1
# 20     20      1
# 21     21      1
# 22     22      1
# 23     23      0
# 24     24      0
